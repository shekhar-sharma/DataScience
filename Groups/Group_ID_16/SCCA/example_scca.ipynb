# %%
import numpy as np
from scca import *

# %%
# Example
N = 10 # number of instances
NVECS = 2 # number of reduced dimensions

# Generate random data
X = np.random.rand(N, 3)
Y = np.random.rand(N, 4)

# Center X to it's mean
X_mean = X.mean(axis = 0)
X = X - X_mean
# Center Y to it's mean
Y_mean = Y.mean(axis = 0)
Y = Y - Y_mean

(u_comp, v_comp), (x_proj, y_proj) = scca([X, Y], nvecs = NVECS, verbose = 1)

print(u_comp)
print(v_comp)

print(x_proj)
print(y_proj)
# Out:
# ...
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: -0.5587
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: -0.3004
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: -0.3008
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: -0.3012
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: -0.3016
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: -0.3020
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: -0.3024
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: -0.3029
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: -0.3033
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: -0.3038
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: -0.3043
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: -0.3048
# ...
